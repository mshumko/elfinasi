# %%
from datetime import datetime, timedelta
import string
import dateutil.parser

import asilib
import asilib.map
import asilib.asi
import matplotlib.dates
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy
import IRBEM
import numpy as np
import pandas as pd
import pyspedas
import manylabels
import aacgmv2

import elfinasi

# %%
R_E = 6378.137  # km
time_range_str = ('2022-09-04T04:23:00', '2022-09-04T04:28:00')
time_range = [dateutil.parser.parse(t) for t in time_range_str]
plot_times = (
    datetime(2022, 9, 4, 4, 24, 00),
    datetime(2022, 9, 4, 4, 25, 00),
    datetime(2022, 9, 4, 4, 25, 50),
    datetime(2022, 9, 4, 4, 27, 00),
)
location_codes = ('ATHA', 'PINA', 'GILL', 'RABB', 'LUCK')
poes_probe = 'noaa18'
alt=90

# %%
def map_poes(df, alt=110, hemi_flag=0):
    """
    Map POES's location along the magnetic field line to alt using IRBEM.MagFields.find_foot_print.

    Parameters
    ----------
    alt: float
        The mapping altitude in units of kilometers
    hemi_flag: int
        What direction to trace the field line: 
        0 = same magnetic hemisphere as starting point
        +1   = northern magnetic hemisphere
        -1   = southern magnetic hemisphere
        +2   = opposite magnetic hemisphere as starting point
    """
    m = IRBEM.MagFields(kext='T89')
    _all = np.zeros_like(df.loc[:, ['alt', 'lat', 'lon']])

    for i, (time, row) in enumerate(df.iterrows()):
        X = {'Time':time, 'x1':row['alt'], 'x2':row['lat'], 'x3':row['lon']}
        _all[i, :] = m.find_foot_point(X, {'Kp':56}, alt, hemi_flag)['XFOOT']
    _all[_all == -1E31] = np.nan
    mapped_df = df.copy()
    mapped_df.loc[:, ['alt', 'lat', 'lon']] = _all
    return mapped_df

# %%
poes = elfinasi.poes(time_range[0], poes_probe)[poes_probe]

# %%
poes
# Out:
# {'time': DatetimeIndex(['2022-09-04 00:00:00.166000', '2022-09-04 00:00:02.166000',
#                 '2022-09-04 00:00:04.166000', '2022-09-04 00:00:06.166000',
#                 '2022-09-04 00:00:08.166000', '2022-09-04 00:00:10.166000',
#                 '2022-09-04 00:00:12.166000', '2022-09-04 00:00:14.166000',
#                 '2022-09-04 00:00:16.166000', '2022-09-04 00:00:18.163000',
#                 ...
#                 '2022-09-04 23:59:38.160000', '2022-09-04 23:59:40.160000',
#                 '2022-09-04 23:59:42.160000', '2022-09-04 23:59:44.160000',
#                 '2022-09-04 23:59:46.160000', '2022-09-04 23:59:48.160000',
#                 '2022-09-04 23:59:50.160000', '2022-09-04 23:59:52.160000',
#                 '2022-09-04 23:59:54.160000', '2022-09-04 23:59:56.160000'],
#                dtype='datetime64[ns]', length=43188, freq=None),
#  'year': masked_array(data=[2022, 2022, 2022, ..., 2022, 2022, 2022],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'day': masked_array(data=[247, 247, 247, ..., 247, 247, 247],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'msec': masked_array(data=[     166,     2166,     4166, ..., 86392160, 86394160,
#                     86396160],
#               mask=False,
#         fill_value=999999,
#              dtype=uint32),
#  'satID': masked_array(data=[7, 7, 7, ..., 7, 7, 7],
#               mask=False,
#         fill_value=999999,
#              dtype=uint8),
#  'sat_direction': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=uint8),
#  'alt': masked_array(data=[856. , 856. , 856.1, ..., 880.2, 880.2, 880.3],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'lat': masked_array(data=[-17.082, -17.199, -17.315, ..., -58.756, -58.868,
#                     -58.979],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'lon': masked_array(data=[151.488, 151.46 , 151.432, ..., 139.335, 139.26 ,
#                     139.184],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p1': masked_array(data=[ 4.65658,  6.98487,  4.65658, ..., 60.53551, 62.86379,
#                     69.84866],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p2': masked_array(data=[0.73921, 0.     , 0.     , ..., 0.73921, 0.73921,
#                     0.73921],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p3': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p4': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p5': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p6': masked_array(data=[  0.     ,   0.     ,   0.     , ...,   0.     ,
#                       0.     , 243.90244],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel0_flux_p1_err': masked_array(data=[79, 67, 79, ..., 40, 40, 39],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel0_flux_p2_err': masked_array(data=[106,   0,   0, ..., 106, 106, 106],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel0_flux_p3_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel0_flux_p4_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel0_flux_p5_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel0_flux_p6_err': masked_array(data=[  0,   0,   0, ...,   0,   0, 109],
#               mask=False,
#         fill_value=999999,
#              dtype=uint16),
#  'mep_pro_tel90_flux_p1': masked_array(data=[ 6.98487,  4.65658,  4.65658, ..., 74.50523, 55.87893,
#                     37.25262],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p2': masked_array(data=[0.     , 0.     , 0.     , ..., 0.73921, 1.47842,
#                     0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p3': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p4': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p5': masked_array(data=[0., 0., 0., ..., 0., 0., 0.],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p6': masked_array(data=[  0.     ,   0.     , 243.90244, ...,   0.     ,
#                       0.     , 243.90244],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_pro_tel90_flux_p1_err': masked_array(data=[67, 79, 79, ..., 39, 40, 43],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_pro_tel90_flux_p2_err': masked_array(data=[  0,   0,   0, ..., 106,  79,   0],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_pro_tel90_flux_p3_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_pro_tel90_flux_p4_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_pro_tel90_flux_p5_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_pro_tel90_flux_p6_err': masked_array(data=[  0,   0, 109, ...,   0,   0, 109],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel0_flux_e1': masked_array(data=[ 80.64516, 161.29031,   0.     , ..., 241.93549,
#                     403.2258 , 403.2258 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel0_flux_e2': masked_array(data=[ 69.44444, 138.88889,   0.     , ..., 138.88889,
#                     208.33333,  69.44444],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel0_flux_e3': masked_array(data=[  0.     , 133.33333,   0.     , ..., 266.66666,
#                     133.33333,   0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel0_flux_e4': masked_array(data=[  0.     ,   0.     ,   0.     , ...,   0.     ,
#                       0.     , 181.81818],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel0_flux_e1_err': masked_array(data=[112,  87,   0, ...,  76,  67,  67],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel0_flux_e2_err': masked_array(data=[102,  74,   0, ...,  74,  62, 102],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel0_flux_e3_err': masked_array(data=[  0, 103,   0, ...,  75, 103,   0],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel0_flux_e4_err': masked_array(data=[  0,   0,   0, ...,   0,   0, 124],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel90_flux_e1': masked_array(data=[  0.     ,   0.     ,   0.     , ..., 161.29031,
#                     322.58063, 322.58063],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel90_flux_e2': masked_array(data=[  0.     ,   0.     ,   0.     , ...,   0.     ,
#                     138.88889, 138.88889],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel90_flux_e3': masked_array(data=[  0.     ,   0.     ,   0.     , ...,   0.     ,
#                     133.33333, 133.33333],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel90_flux_e4': masked_array(data=[  0.     ,   0.     , 181.81818, ...,   0.     ,
#                       0.     , 181.81818],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_ele_tel90_flux_e1_err': masked_array(data=[ 0,  0,  0, ..., 87, 71, 71],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel90_flux_e2_err': masked_array(data=[ 0,  0,  0, ...,  0, 74, 74],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel90_flux_e3_err': masked_array(data=[  0,   0,   0, ...,   0, 103, 103],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_ele_tel90_flux_e4_err': masked_array(data=[  0,   0, 124, ...,   0,   0, 124],
#               mask=False,
#         fill_value=999999,
#              dtype=int16),
#  'mep_omni_flux_p1': masked_array(data=[0.0366, 0.008 , 0.0259, ..., 0.0418, 0.0102, 0.0073],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_omni_flux_p2': masked_array(data=[0.0049, 0.0011, 0.0035, ..., 0.0095, 0.0014, 0.001 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_omni_flux_p3': masked_array(data=[7.0e-04, 1.0e-04, 5.0e-04, ..., 2.2e-03, 2.0e-04,
#                     1.0e-04],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_omni_flux_flag_fit': masked_array(data=[1, 1, 1, ..., 2, 1, 1],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'mep_omni_flux_flag_iter_lim': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'mep_omni_gamma_p1': masked_array(data=[-2.9, -2.9, -2.9, ..., -2.1, -2.9, -2.9],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_omni_gamma_p2': masked_array(data=[-2.9, -2.9, -2.9, ..., -2.1, -2.9, -2.9],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mep_omni_gamma_p3': masked_array(data=[-2.9, -2.9, -2.9, ..., -2.1, -2.9, -2.9],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_tel0_flux_4': masked_array(data=[--, 730.7999877929688, --, ..., --, 455836.5, --],
#               mask=[ True, False,  True, ...,  True, False,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel0_flux_8': masked_array(data=[--, 0.0, --, ..., --, 0.0, --],
#               mask=[ True, False,  True, ...,  True, False,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel0_flux_11': masked_array(data=[--, 0.0, --, ..., --, 0.0, --],
#               mask=[ True, False,  True, ...,  True, False,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel0_flux_14': masked_array(data=[--, 27.479999542236328, --, ..., --, 0.0, --],
#               mask=[ True, False,  True, ...,  True, False,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel30_flux_4': masked_array(data=[--, --, 571.4000244140625, ..., --, --,
#                     15142.1005859375],
#               mask=[ True,  True, False, ...,  True,  True, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel30_flux_8': masked_array(data=[--, --, 0.0, ..., --, --, 0.0],
#               mask=[ True,  True, False, ...,  True,  True, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel30_flux_11': masked_array(data=[--, --, 33.91999816894531, ..., --, --,
#                     67.83999633789062],
#               mask=[ True,  True, False, ...,  True,  True, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel30_flux_14': masked_array(data=[--, --, 15.819999694824219, ..., --, --, 0.0],
#               mask=[ True,  True, False, ...,  True,  True, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel0_flux_4': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel0_flux_8': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel0_flux_11': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel0_flux_14': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel30_flux_4': masked_array(data=[0.0, --, --, ..., 6325.55029296875, --, --],
#               mask=[False,  True,  True, ..., False,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel30_flux_8': masked_array(data=[525.5800170898438, --, --, ..., 6677.2548828125, --,
#                     --],
#               mask=[False,  True,  True, ..., False,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel30_flux_11': masked_array(data=[0.0, --, --, ..., 50.04999923706055, --, --],
#               mask=[False,  True,  True, ..., False,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_pro_tel30_flux_14': masked_array(data=[0.0, --, --, ..., 11.029999732971191, --, --],
#               mask=[False,  True,  True, ..., False,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_ele_tel0_low_eflux': masked_array(data=[1.0412500e-04, 9.9224999e-05, 8.9424997e-05, ...,
#                     5.9491741e-03, 2.8037876e-02, 4.9681789e-03],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_tel30_low_eflux': masked_array(data=[1.1554000e-04, 1.5151000e-04, 8.3929997e-05, ...,
#                     2.9704883e-03, 9.7397631e-03, 2.4175178e-03],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_tel0_hi_eflux': masked_array(data=[-0.06976613, -0.0669852 , -0.06614586, ...,
#                     -0.00242447, -0.00303881, -0.00357224],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_tel30_hi_eflux': masked_array(data=[-0.03101826, -0.03399156, -0.02912635, ...,
#                     -0.01953682, -0.02229435, -0.02235338],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_tel0_low_eflux': masked_array(data=[-0.00020479, -0.00020305, -0.00022543, ...,
#                      0.00489362,  0.00613599,  0.00279019],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_tel30_low_eflux': masked_array(data=[0.00036769, 0.00050782, 0.00038395, ..., 0.00613416,
#                     0.0069086 , 0.00336305],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_tel0_hi_eflux': masked_array(data=[-0.0020634, -0.002546 , -0.001387 , ..., -0.0026866,
#                      0.0105716, -0.004959 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_tel30_hi_eflux': masked_array(data=[ 0.        ,  0.        ,  0.        , ...,
#                     -0.0028165 , -0.00285413, -0.00349375],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_tel0_low_eflux_error': masked_array(data=[15, 16, 17, ...,  2,  1,  2],
#               mask=False,
#         fill_value=999999),
#  'ted_ele_tel30_low_eflux_error': masked_array(data=[14, 12, 16, ...,  3,  1,  3],
#               mask=False,
#         fill_value=999999),
#  'ted_ele_tel0_hi_eflux_error': masked_array(data=[ 3,  4,  3, ..., 20, 17, 16],
#               mask=False,
#         fill_value=999999),
#  'ted_ele_tel30_hi_eflux_error': masked_array(data=[4, 4, 5, ..., 6, 5, 5],
#               mask=False,
#         fill_value=999999),
#  'ted_pro_tel0_low_eflux_error': masked_array(data=[11, 11,  9, ...,  2,  2,  2],
#               mask=False,
#         fill_value=999999),
#  'ted_pro_tel30_low_eflux_error': masked_array(data=[7, 6, 7, ..., 2, 2, 2],
#               mask=False,
#         fill_value=999999),
#  'ted_pro_tel0_hi_eflux_error': masked_array(data=[28, 20, 40, ..., 30, 11, 14],
#               mask=False,
#         fill_value=999999),
#  'ted_pro_tel30_hi_eflux_error': masked_array(data=[ 0,  0,  0, ..., 17, 16, 11],
#               mask=False,
#         fill_value=999999),
#  'ted_ele_eflux_atmo_low': masked_array(data=[0.00033294, 0.00033905, 0.00027799, ..., 0.01060027,
#                     0.0383461 , 0.00866902],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_atmo_hi': masked_array(data=[-0.19940598, -0.19319682, -0.18794169, ...,
#                     -0.05409098, -0.06188663, -0.06231587],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_atmo_total': masked_array(data=[-0.19907305, -0.19285777, -0.18766369, ...,
#                     -0.04349072, -0.02354053, -0.05364686],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_atmo_low_err': masked_array(data=[0, 0, 0, ..., 0, 0, 0],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_ele_eflux_atmo_hi_err': masked_array(data=[4, 4, 4, ..., 7, 6, 6],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_ele_eflux_atmo_total_err': masked_array(data=[4, 4, 4, ..., 8, 15, 7],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_pro_eflux_atmo_low': masked_array(data=[-0.00035126, -0.00026638, -0.00038127, ...,
#                      0.01874285,  0.02137687,  0.01032408],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_atmo_hi': masked_array(data=[-0.00542953, -0.00666788, -0.00361324, ...,
#                     -0.00879299, -0.00328181, -0.011593  ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_atmo_total': masked_array(data=[-0.00578079, -0.00693427, -0.00399451, ...,
#                      0.00994986,  0.01809506, -0.00126893],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_atmo_low_err': masked_array(data=[35, 51, 33, ..., 2, 2, 2],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_pro_eflux_atmo_hi_err': masked_array(data=[28, 20, 40, ..., 18, 47, 11],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_pro_eflux_atmo_total_err': masked_array(data=[26, 20, 36, ..., 16, 9, 101],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_total_eflux_atmo': masked_array(data=[-0.20485383, -0.19979204, -0.1916582 , ...,
#                     -0.03354085, -0.00544547, -0.05491578],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_total_eflux_atmo_err': masked_array(data=[4, 4, 4, ..., 12, 70, 7],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=-2147483647),
#  'ted_ele_energy_tel0': masked_array(data=[12, 13,  3, ...,  0,  3,  1],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'ted_ele_energy_tel30': masked_array(data=[15,  8, 15, ..., 15,  3,  1],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'ted_pro_energy_tel0': masked_array(data=[8, 8, 8, ..., 7, 8, 6],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'ted_pro_energy_tel30': masked_array(data=[7, 7, 7, ..., 7, 7, 7],
#               mask=False,
#         fill_value=999999,
#              dtype=int8),
#  'ted_ele_max_flux_tel0': masked_array(data=[3.451000e+01, 2.748000e+01, 1.096200e+03, ...,
#                     6.895860e+05, 4.558365e+05, 5.555088e+05],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_max_flux_tel30': masked_array(data=[9.5260000e+00, 1.1272000e+02, 1.9052000e+01, ...,
#                     9.5260000e+00, 1.7813395e+05, 2.2466500e+05],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_max_flux_tel0': masked_array(data=[ 961.    ,  961.    , 1922.    , ..., 6097.3896,
#                     4805.    , 4865.5   ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_max_flux_tel30': masked_array(data=[ 525.57996,  764.48   ,  597.25   , ..., 6677.255  ,
#                     7441.735  , 2233.7148 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel0_low': masked_array(data=[0.       , 0.       , 0.       , ..., 0.0001648,
#                     0.0001849, 0.000205 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel30_low': masked_array(data=[0.00000e+00, 0.00000e+00, 0.00000e+00, ...,
#                     2.81016e-05, 2.55469e-05, 2.29922e-05],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel0_hi': masked_array(data=[0.07041334, 0.0682796 , 0.06614586, ..., 0.00266717,
#                     0.00320061, 0.00373404],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel30_hi': masked_array(data=[0.03405086, 0.03409436, 0.03413785, ..., 0.02290352,
#                     0.02296255, 0.02302158],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel0_low': masked_array(data=[0.00027983, 0.00027407, 0.00026831, ..., 0.00020843,
#                     0.00020958, 0.00021074],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel30_low': masked_array(data=[5.156250e-05, 5.542970e-05, 5.929690e-05, ...,
#                     2.010938e-04, 1.946484e-04, 1.882031e-04],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel0_hi': masked_array(data=[0.003705, 0.003458, 0.003211, ..., 0.006669, 0.006422,
#                     0.006175],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel30_hi': masked_array(data=[0.        , 0.        , 0.        , ..., 0.0041925 ,
#                     0.00384312, 0.00349375],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel0_low_cps': masked_array(data=[0.  , 0.  , 0.  , ..., 2.56, 2.88, 3.19],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel30_low_cps': masked_array(data=[0.  , 0.  , 0.  , ..., 0.69, 0.62, 0.56],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel0_hi_cps': masked_array(data=[16.5 , 16.  , 15.5 , ...,  0.62,  0.75,  0.88],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_ele_eflux_bg_tel30_hi_cps': masked_array(data=[18.03, 18.05, 18.07, ..., 12.12, 12.16, 12.19],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel0_low_cps': masked_array(data=[15.19, 14.88, 14.56, ..., 11.31, 11.38, 11.44],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel30_low_cps': masked_array(data=[2.5 , 2.69, 2.88, ..., 9.75, 9.44, 9.12],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel0_hi_cps': masked_array(data=[1.88, 1.75, 1.62, ..., 3.38, 3.25, 3.12],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_pro_eflux_bg_tel30_hi_cps': masked_array(data=[0.  , 0.  , 0.  , ..., 3.  , 2.75, 2.5 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Br_sat': masked_array(data=[22016.51953125, 22118.279296875, 22218.869140625, ...,
#                     --, --, --],
#               mask=[False, False, False, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'Bt_sat': masked_array(data=[-21909.34, -21880.35, -21850.19, ...,  -3410.88,
#                      -3348.29,  -3285.66],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Bp_sat': masked_array(data=[2998.35, 3000.15, 3001.79, ..., 1270.71, 1250.59,
#                     1230.27],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Btot_sat': masked_array(data=[31204.75, 31256.509765625, 31306.859375, ..., --, --,
#                     --],
#               mask=[False, False, False, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'Br_foot': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'Bt_foot': masked_array(data=[-28827.859375, -28785.7109375, -28743.029296875, ...,
#                     -3950.080078125, -3862.860107421875, -3775.6298828125],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'Bp_foot': masked_array(data=[4575.68, 4576.2 , 4576.74, ..., 1710.8 , 1678.82,
#                     1646.59],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Btot_foot': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'geod_lat_foot': masked_array(data=[-22.41, -22.5 , -22.59, ..., -59.06, -59.16, -59.26],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'geod_lon_foot': masked_array(data=[150.64, 150.61, 150.59, ..., 138.99, 138.92, 138.85],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'aacgm_lat_foot': masked_array(data=[-31.35, -31.45, -31.55, ..., -72.9 , -73.01, -73.13],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'aacgm_lon_foot': masked_array(data=[225.63, 225.61, 225.6 , ..., 223.28, 223.24, 223.2 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mag_lat_foot': masked_array(data=[-31.17, -31.27, -31.36, ..., -68.74, -68.85, -68.96],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mag_lon_foot': masked_array(data=[222.54, 222.53, 222.52, ..., 220.06, 220.03, 220.  ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mag_lat_sat': masked_array(data=[-25.7 , -25.81, -25.93, ..., -68.26, -68.37, -68.49],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'mag_lon_sat': masked_array(data=[222.56, 222.55, 222.54, ..., 220.1 , 220.07, 220.04],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Bx_sat': masked_array(data=[-22016.51953125, -22118.279296875, -22218.869140625,
#                     ..., --, --, --],
#               mask=[False, False, False, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'By_sat': masked_array(data=[22018.82, 21992.78, 21962.92, ...,  3639.21,  3573.58,
#                      3507.82],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'Bz_sat': masked_array(data=[-2044.8 , -2016.98, -2017.82, ...,    70.55,    67.78,
#                        65.75],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_alpha_0_sat': masked_array(data=[134.87, 135.04, 135.21, ..., 175.24, 175.32, 175.41],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_alpha_30_sat': masked_array(data=[130.07, 130.17, 130.3 , ..., 149.57, 149.58, 149.6 ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_alpha_0_foot': masked_array(data=[118.75, 119.08000183105469, 119.4000015258789, ...,
#                     174.27999877929688, 174.3800048828125,
#                     174.47999572753906],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'ted_alpha_30_foot': masked_array(data=[108.79000091552734, 109.06999969482422,
#                     109.41999816894531, ..., 142.52000427246094,
#                     142.5399932861328, 142.55999755859375],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'meped_alpha_0_sat': masked_array(data=[133.6 , 133.75, 133.92, ..., 169.11, 169.16, 169.21],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'meped_alpha_90_sat': masked_array(data=[135.  , 134.83, 134.66, ...,  94.69,  94.6 ,  94.52],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'meped_alpha_0_foot': masked_array(data=[116.36000061035156, 116.68000030517578,
#                     117.0199966430664, ..., 166.8800048828125,
#                     166.94000244140625, 167.0],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'meped_alpha_90_foot': masked_array(data=[118.9800033569336, 118.69000244140625,
#                     118.4000015258789, ..., --, --, --],
#               mask=[False, False, False, ...,  True,  True,  True],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'L_IGRF': masked_array(data=[1.3300000429153442, 1.3300000429153442,
#                     1.3300000429153442, ..., 10.729999542236328,
#                     10.859999656677246, 11.010000228881836],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value=9.96921e+36,
#              dtype=float32),
#  'MLT': masked_array(data=[10.33, 10.33, 10.33, ..., 10.17, 10.17, 10.17],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  'ted_IFC_on': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=-127,
#              dtype=int8),
#  'mep_IFC_on': masked_array(data=[--, --, --, ..., --, --, --],
#               mask=[ True,  True,  True, ...,  True,  True,  True],
#         fill_value=-127,
#              dtype=int8)}

# %%
ephemeris_df = pd.DataFrame(
    index=poes['time'],
    data={
        'alt':poes['alt'],
        'lat':poes['lat'],
        'lon':poes['lon'],
    }
)
ephemeris_df = ephemeris_df.loc[time_range_str[0]:time_range_str[1]]
mapped_ephemeris = map_poes(ephemeris_df, alt=alt)

aacgm_lats = aacgmv2.convert_latlon_arr(
        ephemeris_df.lat,
        ephemeris_df.lon,
        ephemeris_df.alt,
        pd.to_datetime(ephemeris_df.index).to_pydatetime()[0],
        method_code="G2A",
    )[0]
mapped_ephemeris['mlat'] = aacgm_lats

manylabels_data = pd.DataFrame(
    index=mapped_ephemeris.index,
    data={
        'Alt [km]':mapped_ephemeris.alt,
        f'Geo Lat [$\\circ$]':mapped_ephemeris.lat,
        f'Geo Lon [$\\circ$]':mapped_ephemeris.lon,
        f'$\\lambda$ [$\\circ$]':mapped_ephemeris.mlat.astype(np.float32),
        }
).round(2)

# %%
manylabels_data.tail()
# Out:
#                           Alt [km]  Geo Lat [$\circ$]  Geo Lon [$\circ$]  \
# 2022-09-04 04:27:52.163  89.940002          62.220001        -108.779999
# 2022-09-04 04:27:54.163  89.930000          62.330002        -108.870003
# 2022-09-04 04:27:56.163  89.919998          62.430000        -108.949997
# 2022-09-04 04:27:58.163  89.980003          62.540001        -109.040001
# 2022-09-04 04:28:00.163  89.930000          62.639999        -109.129997
#
#                          $\lambda$ [$\circ$]
# 2022-09-04 04:27:52.163            69.250000
# 2022-09-04 04:27:54.163            69.330002
# 2022-09-04 04:27:56.163            69.419998
# 2022-09-04 04:27:58.163            69.510002
# 2022-09-04 04:28:00.163            69.599998

# %%
poes.keys()
# Out:
# dict_keys(['time', 'year', 'day', 'msec', 'satID', 'sat_direction', 'alt', 'lat', 'lon', 'mep_pro_tel0_flux_p1', 'mep_pro_tel0_flux_p2', 'mep_pro_tel0_flux_p3', 'mep_pro_tel0_flux_p4', 'mep_pro_tel0_flux_p5', 'mep_pro_tel0_flux_p6', 'mep_pro_tel0_flux_p1_err', 'mep_pro_tel0_flux_p2_err', 'mep_pro_tel0_flux_p3_err', 'mep_pro_tel0_flux_p4_err', 'mep_pro_tel0_flux_p5_err', 'mep_pro_tel0_flux_p6_err', 'mep_pro_tel90_flux_p1', 'mep_pro_tel90_flux_p2', 'mep_pro_tel90_flux_p3', 'mep_pro_tel90_flux_p4', 'mep_pro_tel90_flux_p5', 'mep_pro_tel90_flux_p6', 'mep_pro_tel90_flux_p1_err', 'mep_pro_tel90_flux_p2_err', 'mep_pro_tel90_flux_p3_err', 'mep_pro_tel90_flux_p4_err', 'mep_pro_tel90_flux_p5_err', 'mep_pro_tel90_flux_p6_err', 'mep_ele_tel0_flux_e1', 'mep_ele_tel0_flux_e2', 'mep_ele_tel0_flux_e3', 'mep_ele_tel0_flux_e4', 'mep_ele_tel0_flux_e1_err', 'mep_ele_tel0_flux_e2_err', 'mep_ele_tel0_flux_e3_err', 'mep_ele_tel0_flux_e4_err', 'mep_ele_tel90_flux_e1', 'mep_ele_tel90_flux_e2', 'mep_ele_tel90_flux_e3', 'mep_ele_tel90_flux_e4', 'mep_ele_tel90_flux_e1_err', 'mep_ele_tel90_flux_e2_err', 'mep_ele_tel90_flux_e3_err', 'mep_ele_tel90_flux_e4_err', 'mep_omni_flux_p1', 'mep_omni_flux_p2', 'mep_omni_flux_p3', 'mep_omni_flux_flag_fit', 'mep_omni_flux_flag_iter_lim', 'mep_omni_gamma_p1', 'mep_omni_gamma_p2', 'mep_omni_gamma_p3', 'ted_ele_tel0_flux_4', 'ted_ele_tel0_flux_8', 'ted_ele_tel0_flux_11', 'ted_ele_tel0_flux_14', 'ted_ele_tel30_flux_4', 'ted_ele_tel30_flux_8', 'ted_ele_tel30_flux_11', 'ted_ele_tel30_flux_14', 'ted_pro_tel0_flux_4', 'ted_pro_tel0_flux_8', 'ted_pro_tel0_flux_11', 'ted_pro_tel0_flux_14', 'ted_pro_tel30_flux_4', 'ted_pro_tel30_flux_8', 'ted_pro_tel30_flux_11', 'ted_pro_tel30_flux_14', 'ted_ele_tel0_low_eflux', 'ted_ele_tel30_low_eflux', 'ted_ele_tel0_hi_eflux', 'ted_ele_tel30_hi_eflux', 'ted_pro_tel0_low_eflux', 'ted_pro_tel30_low_eflux', 'ted_pro_tel0_hi_eflux', 'ted_pro_tel30_hi_eflux', 'ted_ele_tel0_low_eflux_error', 'ted_ele_tel30_low_eflux_error', 'ted_ele_tel0_hi_eflux_error', 'ted_ele_tel30_hi_eflux_error', 'ted_pro_tel0_low_eflux_error', 'ted_pro_tel30_low_eflux_error', 'ted_pro_tel0_hi_eflux_error', 'ted_pro_tel30_hi_eflux_error', 'ted_ele_eflux_atmo_low', 'ted_ele_eflux_atmo_hi', 'ted_ele_eflux_atmo_total', 'ted_ele_eflux_atmo_low_err', 'ted_ele_eflux_atmo_hi_err', 'ted_ele_eflux_atmo_total_err', 'ted_pro_eflux_atmo_low', 'ted_pro_eflux_atmo_hi', 'ted_pro_eflux_atmo_total', 'ted_pro_eflux_atmo_low_err', 'ted_pro_eflux_atmo_hi_err', 'ted_pro_eflux_atmo_total_err', 'ted_total_eflux_atmo', 'ted_total_eflux_atmo_err', 'ted_ele_energy_tel0', 'ted_ele_energy_tel30', 'ted_pro_energy_tel0', 'ted_pro_energy_tel30', 'ted_ele_max_flux_tel0', 'ted_ele_max_flux_tel30', 'ted_pro_max_flux_tel0', 'ted_pro_max_flux_tel30', 'ted_ele_eflux_bg_tel0_low', 'ted_ele_eflux_bg_tel30_low', 'ted_ele_eflux_bg_tel0_hi', 'ted_ele_eflux_bg_tel30_hi', 'ted_pro_eflux_bg_tel0_low', 'ted_pro_eflux_bg_tel30_low', 'ted_pro_eflux_bg_tel0_hi', 'ted_pro_eflux_bg_tel30_hi', 'ted_ele_eflux_bg_tel0_low_cps', 'ted_ele_eflux_bg_tel30_low_cps', 'ted_ele_eflux_bg_tel0_hi_cps', 'ted_ele_eflux_bg_tel30_hi_cps', 'ted_pro_eflux_bg_tel0_low_cps', 'ted_pro_eflux_bg_tel30_low_cps', 'ted_pro_eflux_bg_tel0_hi_cps', 'ted_pro_eflux_bg_tel30_hi_cps', 'Br_sat', 'Bt_sat', 'Bp_sat', 'Btot_sat', 'Br_foot', 'Bt_foot', 'Bp_foot', 'Btot_foot', 'geod_lat_foot', 'geod_lon_foot', 'aacgm_lat_foot', 'aacgm_lon_foot', 'mag_lat_foot', 'mag_lon_foot', 'mag_lat_sat', 'mag_lon_sat', 'Bx_sat', 'By_sat', 'Bz_sat', 'ted_alpha_0_sat', 'ted_alpha_30_sat', 'ted_alpha_0_foot', 'ted_alpha_30_foot', 'meped_alpha_0_sat', 'meped_alpha_90_sat', 'meped_alpha_0_foot', 'meped_alpha_90_foot', 'L_IGRF', 'MLT', 'ted_IFC_on', 'mep_IFC_on'])

# %%
meped_flux_units = poes.attrs['mep_ele_tel0_flux_e1'].units
ted_eflux_units = poes.attrs['ted_ele_tel0_low_eflux'].units

# %%
meped_channels_0deg = ['mep_ele_tel0_flux_e1', 'mep_ele_tel0_flux_e2', 'mep_ele_tel0_flux_e3', 'mep_ele_tel0_flux_e4']
meped_channels_90deg = ['mep_ele_tel90_flux_e1', 'mep_ele_tel90_flux_e2', 'mep_ele_tel90_flux_e3', 'mep_ele_tel90_flux_e4']

# %%
# # The energy channel values are from the bowtie analysis
# # (https://www.ngdc.noaa.gov/stp/satellite/poes/docs/NGDC/MEPED%20telescope%20processing%20ATBD_V1.pdf)
# meped_energy_channels = np.array(sorted(set(meped_df['energy_keV'])))
# E1-E3 channel labels from Yando+2011 (https://doi.org/10.1029/2011JA016671).
meped_energy_labels = np.array(['E1: >30', 'E2: >100', 'E3: >300', 'E4: >700'])

# %%
manylabels_data
# Out:
#                           Alt [km]  Geo Lat [$\circ$]  Geo Lon [$\circ$]  \
# 2022-09-04 04:23:00.163  89.099998          46.730000        -100.110001
# 2022-09-04 04:23:02.163  89.989998          46.830002        -100.150002
# 2022-09-04 04:23:04.163  89.970001          46.939999        -100.199997
# 2022-09-04 04:23:06.163  90.000000          47.040001        -100.239998
# 2022-09-04 04:23:08.163  90.000000          47.150002        -100.279999
# ...                            ...                ...                ...
# 2022-09-04 04:27:52.163  89.940002          62.220001        -108.779999
# 2022-09-04 04:27:54.163  89.930000          62.330002        -108.870003
# 2022-09-04 04:27:56.163  89.919998          62.430000        -108.949997
# 2022-09-04 04:27:58.163  89.980003          62.540001        -109.040001
# 2022-09-04 04:28:00.163  89.930000          62.639999        -109.129997
#
#                          $\lambda$ [$\circ$]
# 2022-09-04 04:23:00.163            55.540001
# 2022-09-04 04:23:02.163            55.639999
# 2022-09-04 04:23:04.163            55.730000
# 2022-09-04 04:23:06.163            55.830002
# 2022-09-04 04:23:08.163            55.930000
# ...                                      ...
# 2022-09-04 04:27:52.163            69.250000
# 2022-09-04 04:27:54.163            69.330002
# 2022-09-04 04:27:56.163            69.419998
# 2022-09-04 04:27:58.163            69.510002
# 2022-09-04 04:28:00.163            69.599998
#
# [151 rows x 4 columns]

# %%
poes.attrs['ted_ele_tel0_low_eflux'].units
# Out:
# 'mW/m2-str'

# %%
fig, bx = plt.subplots(2, 1, sharex=True)
colors = ('orange', 'green', 'purple', 'black')
for meped_channel_0deg, meped_channel_90deg, color, energy_label in zip(meped_channels_0deg, meped_channels_90deg, colors, meped_energy_labels):
    bx[0].plot(poes['time'], poes[meped_channel_0deg], color=color, label=f'{energy_label} keV')
    bx[0].plot(poes['time'], poes[meped_channel_90deg], color=color, ls='--')

bx[1].plot(poes['time'], poes['ted_ele_tel0_low_eflux'], label='low: 0.05-1 keV')
bx[1].plot(poes['time'], poes['ted_ele_tel0_hi_eflux'], c='k', label='high: 1-20 keV')
bx[1].text(0.01, 0.99, f'TED $0^{{\\circ}}$ telescope | energy flux', va='top', transform=bx[1].transAxes)
bx[0].set_yscale('log')
bx[0].set_ylabel(meped_flux_units)
bx[1].set_yscale('log')
bx[1].set_ylabel(ted_eflux_units)
bx[0].legend();
bx[1].legend(loc=1);
manylabels.ManyLabels(bx[1], manylabels_data)
bx[1].xaxis.label.set_size(9)
bx[1].xaxis.set_label_coords(-0.05, -0.02*(1+len(manylabels_data.columns)))
bx[1].xaxis.set_major_locator(plt.MaxNLocator(7))
bx[-1].set_xlim(*time_range);
# Out:
# 11-Sep-25 17:13:36: c:\Users\shumkms1\AppData\Local\anaconda3\envs\asilib_dev_20241108\Lib\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
asis = asilib.Imagers(
        [asilib.asi.trex_rgb(location_code=location_code, time=time_range[0], alt=alt) 
        for location_code in location_codes]
        )
# Out:
# Transition Region Explorer (TREx) RGB data is courtesy of Space Environment Canada (space-environment.ca). Use of the data must adhere to the rules of the road for that dataset.  Please see below for the required data acknowledgement. Any questions about the TREx instrumentation or data should be directed to the University of Calgary, Emma Spanswick (elspansw@ucalgary.ca) and/or Eric Donovan (edonovan@ucalgary.ca).
#
# “The Transition Region Explorer RGB (TREx RGB) is a joint Canada Foundation for Innovation and Canadian Space Agency project developed by the University of Calgary. TREx-RGB is operated and maintained by Space Environment Canada with the support of the Canadian Space Agency (CSA) [23SUGOSEC].”

# %%
fig = plt.figure(figsize=(9, 6))
# Add a gridspec with two rows and two columns and a ratio of 1 to 4 between
# the size of the marginal Axes and the main Axes in both directions.
# Also adjust the subplot parameters for a square plot.
gs = fig.add_gridspec(3, len(plot_times),
                      right=0.95, bottom=0.25, top=0.97,
                      wspace=0.02, hspace=0.05,
                      height_ratios=(2, 1, 1))

ax = [
    asilib.map.create_map(
        lon_bounds=(-115, -88), 
        lat_bounds=(45, 63.5), 
        fig_ax=(fig, gs[0, i],),
        land_color='grey'
        ) for i in range(gs.ncols)
    ]
bx = fig.add_subplot(gs[1, :])
cx = fig.add_subplot(gs[2, :], sharex=bx)

ephemeris_indices = mapped_ephemeris.index.get_indexer(plot_times, method='nearest')
mapped_ephemeris_snapshots = mapped_ephemeris.iloc[ephemeris_indices, :]

for i, (time, ax_i, _label) in enumerate(zip(plot_times, ax, string.ascii_lowercase)):
    asis = asilib.Imagers(
        [asilib.asi.trex_rgb(location_code=location_code, time=time, alt=alt) 
        for location_code in location_codes]
        )
    vmin = min([_imager.get_color_bounds()[0] for _imager in asis.imagers])
    vmax = max([_imager.get_color_bounds()[1] for _imager in asis.imagers])
    asis.plot_map(
        ax=ax_i, 
        min_elevation=7, 
        pcolormesh_kwargs={'rasterized':True}, 
        asi_label=False, 
        color_bounds=(vmin, vmax)
        )
    
    ax_i.plot(mapped_ephemeris['lon'], mapped_ephemeris['lat'], c='w', transform=ccrs.PlateCarree())

    _noaa_loc = ax_i.scatter(
        mapped_ephemeris_snapshots.iloc[i]['lon'], 
        mapped_ephemeris_snapshots.iloc[i]['lat'], 
        c='w', 
        s=30,
        transform=ccrs.PlateCarree(),
        label=poes_probe
        )
    if not '_legend' in locals():
        _legend = ax[0].legend(loc='lower left', ncols=2, columnspacing=0.1, handletextpad=0.1, fontsize=8)
    _plot_time = ax_i.text(
        0.01, 0.99, f'({_label}) {time:%H:%M:%S}', va='top', transform=ax_i.transAxes, fontsize=12
        )
    
del(_legend)
colors = ('orange', 'green', 'purple', 'black')
for meped_channel_0deg, meped_channel_90deg, color, energy_label in zip(meped_channels_0deg, meped_channels_90deg, colors, meped_energy_labels):
    bx.plot(poes['time'], poes[meped_channel_0deg], color=color, label=f'{energy_label} keV')
    bx.plot(poes['time'], poes[meped_channel_90deg], color=color, ls='--')
bx.set_yscale('log')
bx.set_ylabel(f'[{meped_flux_units}]')
bx.set_xlim(plot_times[0]-timedelta(minutes=1), plot_times[-1]+timedelta(minutes=1))
bx.legend()

# Connect the subplots and add vertical lines to bx and cx.
for ax_i, image_time_numeric in zip(ax, matplotlib.dates.date2num(plot_times)):
    line = matplotlib.patches.ConnectionPatch(
        xyA=(0.5, 0), coordsA=ax_i.transAxes,
        xyB=(image_time_numeric, bx.get_ylim()[1]), coordsB=bx.transData, 
        ls='--')
    ax_i.add_artist(line)

    bx.axvline(image_time_numeric, c='k', ls='--')
    cx.axvline(image_time_numeric, c='k', ls='--')
_text = bx.text(
    0.01, 
    0.99, 
    (f'({string.ascii_lowercase[len(ax)]}) MEPED (solid $0^{{\\circ}}$, dashed $90^{{\\circ}}$)'), 
    va='top', 
    transform=bx.transAxes, 
    fontsize=12
    )

cx.plot(poes['time'], poes['ted_ele_tel0_low_eflux'], label='low: 0.05-1 keV')
cx.plot(poes['time'], poes['ted_ele_tel0_hi_eflux'], c='k', label='high: 1-20 keV')
cx.text(0.01, 0.99, f'({string.ascii_lowercase[len(ax+1)]}) TED $0^{{\\circ}}$ tel', va='top', transform=cx.transAxes, fontsize=12)
cx.set_yscale('log')
cx.set_ylabel(ted_eflux_units)
cx.legend(loc=1)
cx.set_ylim(1E-4, 1E2)

manylabels.ManyLabels(cx, manylabels_data)
cx.xaxis.label.set_size(9)
cx.xaxis.set_label_coords(-0.03, -0.02*(1+len(manylabels_data.columns)))
cx.xaxis.set_major_locator(plt.MaxNLocator(7))
        
plt.suptitle(f'{plot_times[0]:%Y-%m-%d %H:%M} - {plot_times[-1]:%H:%M} | {poes_probe.upper()}-TREx conjunction | {alt} km');
plt.savefig(f'./plots/{plot_times[0]:%Y%m%d_%H%M}_{plot_times[-1]:%H%M}_{poes_probe.lower()}_trex_conjunction.png');

# %%
del(vline_bx)

# %%
fig = plt.figure(figsize=(11, 6))
gs = fig.add_gridspec(2, 2,
                      left=0.01, right=0.95, bottom=0.18, top=0.92,
                      wspace=0.17, hspace=0.05, width_ratios=(1, 1)
                      )
ax = asilib.map.create_map(lon_bounds=(-117, -88), lat_bounds=(43, 63), fig_ax=(fig, gs[:, 0]), land_color='grey')
bx = fig.add_subplot(gs[0, 1])
cx = fig.add_subplot(gs[1, 1], sharex=bx)

asis = asilib.Imagers(
    [asilib.asi.trex_rgb(location_code=location_code, time_range=time_range, alt=alt) 
    for location_code in location_codes]
    )

plt.suptitle(f'TREx/NOAA-{poes_probe[-2:]} Conjunction | {time_range[0].date()} | T89 model | {alt} km map altitude', fontsize=18)

ax.plot(mapped_ephemeris['lon'], mapped_ephemeris['lat'], c='w', transform=ccrs.PlateCarree(), zorder=2.01)
colors = ('orange', 'green', 'purple', 'black')
for meped_channel_0deg, meped_channel_90deg, color, energy_label in zip(meped_channels_0deg, meped_channels_90deg, colors, meped_energy_labels):
    bx.plot(poes['time'], poes[meped_channel_0deg], color=color, label=f'{energy_label} keV')
    bx.plot(poes['time'], poes[meped_channel_90deg], color=color, ls='--')
ax.text(
    0.01, 
    0.01, 
    f'({string.ascii_lowercase[0]}) TREx mosaic & POES track',
    transform=ax.transAxes, 
    fontsize=18
    )
bx.text(
    0.01, 
    0.99, 
    f'({string.ascii_lowercase[1]}) MEPED\n(solid $0^{{\\circ}}$, dashed $90^{{\\circ}}$)', 
    va='top', 
    transform=bx.transAxes, 
    fontsize=18
    )
bx.set_yscale('log')
bx.set_ylabel(meped_flux_units)
bx.set_xlim(plot_times[0]-timedelta(minutes=1), plot_times[-1]+timedelta(minutes=1))
bx.legend()
bx.get_xaxis().set_visible(False)

cx.plot(poes['time'], poes['ted_ele_tel0_low_eflux'], label='low: 0.05-1 keV')
cx.plot(poes['time'], poes['ted_ele_tel0_hi_eflux'], c='k', label='high: 1-20 keV')
cx.text(0.01, 0.99, f'({string.ascii_lowercase[2]}) TED $0^{{\\circ}}$ tel', va='top', transform=cx.transAxes, fontsize=18)
cx.set_yscale('log')
cx.set_ylabel(ted_eflux_units)
cx.legend(loc=1)
cx.set_ylim(1E-4, 1E2)

manylabels.ManyLabels(cx, manylabels_data)
cx.xaxis.label.set_size(9)
cx.xaxis.set_label_coords(-0.03, -0.01*(1+len(manylabels_data.columns)))
cx.xaxis.set_major_locator(plt.MaxNLocator(7))

gen = asis.animate_map_gen(overwrite=True, ax=ax, min_elevation=7)
for _guide_time, _, _, _ in gen:
    if 'vline_bx' in locals():
        # These variables are only used when POES is in the FOV
        vline_bx.remove()
        vline_cx.remove()
        _noaa_loc.remove()

    idx = mapped_ephemeris.index.get_indexer([_guide_time], method='nearest')
    _noaa_loc = ax.scatter(
        mapped_ephemeris.iloc[idx, :]['lon'], 
        mapped_ephemeris.iloc[idx, :]['lat'], 
        c='w',
        s=30,
        transform=ccrs.PlateCarree(),
        label=poes_probe
        )
    vline_bx = bx.axvline(_guide_time, c='k')
    vline_cx = cx.axvline(_guide_time, c='k')
# Out:
# 20220904_042300_042800_mosaic.mp4: |################################### | 98%
# Animation saved to C:\Users\shumkms1\asilib-data\animations\20220904_042300_042800_mosaic.mp4
